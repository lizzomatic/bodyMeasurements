# %% [markdown]
# # Body Measurements data from kaggle

# %% [markdown]
# #### read in data

# %%
df = pd.read_csv("./BodyMeasurements.csv")
df.head()
# Out:
#    Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth   Belly   Waist   \
# 0     1.0   30                 22             18           20      18      14
# 1     1.0   28                 19             22           17      18      21
# 2     2.0   27                 21             18           16      14      10
# 3     1.0   29                 20             20           18      11      19
# 4     2.0   28                 16             14           18      13      11
#
#    Hips   ArmLength   ShoulderToWaist   WaistToKnee   LegLength  TotalHeight
# 0     22          22                25            25         22           52
# 1     25          28                23            25         20           56
# 2     15          21                18            14         18           53
# 3     14          24                21            20         21           45
# 4     30          25                22            32         13           47

# %% [markdown]
# #### divide shoulder width by (center to shoulder measurement)

# %%
df.ShoulderWidth.apply(lambda x: x/2)
# Out:
# 0       9.0
# 1      11.0
# 2       9.0
# 3      10.0
# 4       7.0
#        ...
# 711     3.0
# 712     5.5
# 713     8.5
# 714     7.5
# 715     7.5
# Name: ShoulderWidth, Length: 716, dtype: float64

# %% [markdown]
# #### get info on the dataframe

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             715 non-null    float64
#  1   Age                716 non-null    int64
#  2   HeadCircumference  716 non-null    int64
#  3   ShoulderWidth      716 non-null    int64
#  4   ChestWidth         716 non-null    int64
#  5   Belly              716 non-null    int64
#  6   Waist              716 non-null    int64
#  7   Hips               716 non-null    int64
#  8   ArmLength          716 non-null    int64
#  9   ShoulderToWaist    716 non-null    int64
#  10  WaistToKnee        716 non-null    int64
#  11  LegLength          716 non-null    int64
#  12  TotalHeight        716 non-null    int64
# dtypes: float64(1), int64(12)
# memory usage: 72.8 KB
# /tmp/ipykernel_3281/2612161665.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   df.info(verbose=True, null_counts=True)

# %% [markdown]
# #### convert gender datatype to a string

# %%
df['Gender'] = df['Gender'].astype('str')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             716 non-null    object
#  1   Age                716 non-null    int64
#  2   HeadCircumference  716 non-null    int64
#  3   ShoulderWidth      716 non-null    int64
#  4   ChestWidth         716 non-null    int64
#  5   Belly              716 non-null    int64
#  6   Waist              716 non-null    int64
#  7   Hips               716 non-null    int64
#  8   ArmLength          716 non-null    int64
#  9   ShoulderToWaist    716 non-null    int64
#  10  WaistToKnee        716 non-null    int64
#  11  LegLength          716 non-null    int64
#  12  TotalHeight        716 non-null    int64
# dtypes: int64(12), object(1)
# memory usage: 72.8+ KB

# %% [markdown]
# #### replace gender data

# %%
df['Gender'].replace({'1.0':'M'}, inplace=True)
df['Gender'].replace({'2.0':'F'}, inplace=True)
df.head()
# Out:
#   Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth   Belly   Waist   \
# 0      M   30                 22             18           20      18      14
# 1      M   28                 19             22           17      18      21
# 2      F   27                 21             18           16      14      10
# 3      M   29                 20             20           18      11      19
# 4      F   28                 16             14           18      13      11
#
#    Hips   ArmLength   ShoulderToWaist   WaistToKnee   LegLength  TotalHeight
# 0     22          22                25            25         22           52
# 1     25          28                23            25         20           56
# 2     15          21                18            14         18           53
# 3     14          24                21            20         21           45
# 4     30          25                22            32         13           47

# %% [markdown]
# #### scatter plot

# %%
plt.figure(figsize=(10, 6), dpi=72)
plt.scatter(df['Age'], df['HeadCircumference'])
plt.scatter(df['Age'], df['TotalHeight'])
plt.legend(['HeadCircumference', 'TotalHeight'])

# %% [markdown]
# #### one of the headCircumference datapoints looks like an outlier, lets look at it a different way

# %%
df.describe()
# Out:
#               Age  HeadCircumference  ShoulderWidth  ChestWidth       Belly   \
# count  716.000000         716.000000     716.000000   716.000000  716.000000
# mean    15.340782          20.574022      14.317039    14.569832   20.199721
# std     11.831501           3.743353       4.762181     5.314646   10.132993
# min      1.000000           5.000000       4.000000     6.000000    5.000000
# 25%      7.000000          19.000000      11.000000    11.000000   15.000000
# 50%     11.000000          20.000000      14.000000    13.000000   20.000000
# 75%     21.000000          22.000000      18.000000    17.000000   23.000000
# max     68.000000          80.000000      87.000000    38.000000  213.000000
#
#            Waist        Hips   ArmLength   ShoulderToWaist   WaistToKnee   \
# count  716.000000  716.000000  716.000000        716.000000    716.000000
# mean    19.265363   19.378492   18.817039         17.900838     16.560056
# std      8.770706    8.745223    5.376592          5.379313      5.204411
# min      2.000000    7.000000    6.000000          1.000000      4.000000
# 25%     12.000000   12.000000   16.000000         13.000000     13.000000
# 50%     20.000000   18.000000   19.000000         17.500000     16.000000
# 75%     23.000000   24.000000   22.000000         22.000000     20.000000
# max     91.000000   63.000000   66.000000         39.000000     45.000000
#
#         LegLength  TotalHeight
# count  716.000000   716.000000
# mean    26.833799    48.118715
# std      7.925988    12.156722
# min      9.000000    19.000000
# 25%     21.000000    40.000000
# 50%     26.000000    48.000000
# 75%     32.000000    55.000000
# max     50.000000    89.000000

# %% [markdown]
# #### yep, looks like an outlier, let's look at that row

# %%
df.loc[df.HeadCircumference == 80]
# Out:
#    Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth   Belly   Waist   \
# 21      F   29                 80             19           16      17      20
#
#     Hips   ArmLength   ShoulderToWaist   WaistToKnee   LegLength  TotalHeight
# 21     20          24                22            19         20           44

# %% [markdown]
# #### drop the outlier row

# %%
df.drop(df[df['HeadCircumference'] == 80].index, inplace = True)

# %% [markdown]
# #### let's find other outlier rows

# %%
df.loc[df.ShoulderWidth > 30]
# Out:
#     Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth   Belly   \
# 248      F    2                 11             87           15      13
#
#      Waist   Hips   ArmLength   ShoulderToWaist   WaistToKnee   LegLength  \
# 248      12     14           9                 9             6         13
#
#      TotalHeight
# 248           19

# %% [markdown]
# #### Some of the column names had spaces, let's remove those:

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
df.drop(df[df['ShoulderWidth'] == 87].index, inplace = True)

# %%
df.loc[df.HeadCircumference < 15]
# Out:
#     Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth  Belly  Waist  \
# 35       F   19                 14             22          18     17     13
# 125      F   42                 14             10          12      9     49
# 126      M   40                 12             14          11     18     36
# 128      M   29                 13             18          17     23     19
# 135      M   25                 13             22          14     12     20
# 136      M   32                 11             11          19     14     21
# 139      F   26                 13             14          13     11     17
# 140      F   44                 10             16          10     19     31
# 141      M   25                  9             17           7     10     29
# 142      M   15                 14             18           9      9     12
# 243      F    1                 11              6          16     13     13
# 244      M    1                 12              5          17     12     13
# 245      F    3                 11              6          15     13     12
# 246      M    4                 13              5          18     14     14
# 249      F    1                 12              7          16     13     12
# 272      M    1                 11              6          15     13     12
# 273      F    1                 11              5          16     13     13
# 279      F    1                 12              7          16     13     12
# 301      M    1                 11              6          15     13     12
# 302      F    1                 11              5          16     13     13
# 303      M    1                 12              5          17     12     13
# 304      M    1                 13              5          17     13     14
# 305      F    1                 14              5          18     14     14
# 332      M    3                 11              8          11     19     12
# 494      F    9                 13             13          11     21     22
# 568      F   15                  5             13          23     22     11
#
#      Hips  ArmLength  ShoulderToWaist  WaistToKnee  LegLength  TotalHeight
# 35     20         19               18           13         27           47
# 125    17         20               25           17         13           54
# 126    17         21               23           16         27           64
# 128    13         20               21           19         30           67
# 135    22         21               19           19         22           57
# 136    21         15               21           22         30           48
# 139    17         19               20           30         30           47
# 140    16         20               19           20         29           66
# 141    14         17               18           18         19           49
# 142    15         19               20           21         20           54
# 243    14          9                9            9         13           21
# 244    15          9                9            7         13           20
# 245    14          9               10            8         13           22
# 246    17         10                9            8         14           23
# 249    15         10               10            8         12           20
# 272    14          9                9            6         13           19
# 273    15          9                9            6         13           20
# 279    14         10               10            9         13           25
# 301    14          9                9            6         13           20
# 302    15          9                9            7         13           21
# 303    15         10                9            8         13           22
# 304    16         10                9            8         14           23
# 305    17         10                9            8         15           24
# 332    11         16               10            9         18           32
# 494    11         17               13           15         25           46
# 568    16         16               14           18         50           52

# %% [markdown]
# #### I'm going to drop 'nan' gender values because there's only one row

# %%
df.drop(df[df['Gender'] == 'nan'].index, inplace = True)

# %% [markdown]
# #### Drop some outlier head circumference data, it's sort of arbitrary

# %%
#get bad head circumference data
badData = df[(df['HeadCircumference'] < 20) & (df['Age'] > 10)].index
#drop the bad head circumference data
df.drop(badData, inplace=True)

# %% [markdown]
# #### tests for accuracy

# %%
df.loc[df['ChestWidth'] > 30]
# Out:
#     Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth  Belly  Waist  \
# 262      F   19                 29             19          31     28     28
# 268      F   25                 26             20          37     28     26
# 269      M   26                 26             20          38     27     28
# 270      M   27                 28             20          31     30     32
# 271      F   20                 29             20          32     28     32
# 298      M   21                 26             17          38     27     28
# 299      F   21                 25             18          32     28     31
# 300      M   21                 26             20          31     30     32
# 323      M   19                 28             26          31     28     28
# 324      F   18                 29             19          32     28     27
# 325      M   19                 29             20          31     26     26
#
#      Hips  ArmLength  ShoulderToWaist  WaistToKnee  LegLength  TotalHeight
# 262    28         30               26           30         46           68
# 268    27         28               28           27         42           74
# 269    27         27               26           25         40           85
# 270    38         30               28           27         41           86
# 271    32         28               29           29         42           89
# 298    27         27               26           25         40           85
# 299    31         28               27           26         41           86
# 300    26         29               28           29         42           89
# 323    29         30               26           29         42           68
# 324    29         31               26           30         42           67
# 325    29         30               27           30         42           69

# %% [markdown]
# #### testing the accuracy of this data by checking to see where leg length + torso is longer than total height

# %%
df.loc[(df.LegLength + df.ShoulderToWaist) > df.TotalHeight]
# Out:
#     Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth  Belly  Waist  \
# 30       M   24                 29             20          18     17     18
# 48       M   25                 26             16          14     19     16
# 59       M    6                 17              9           8      8     10
# 60       M    8                 19             15          13      9     15
# 62       F   54                 26             18          13     11     23
# ..     ...  ...                ...            ...         ...    ...    ...
# 699      F    7                 21             11          11     20     22
# 700      F    6                 20             11          10     21     21
# 701      F    7                 20             11          10     20     21
# 707      M   13                 21              8          12     22     14
# 709      M   10                 20             12          12     22     14
#
#      Hips  ArmLength  ShoulderToWaist  WaistToKnee  LegLength  TotalHeight
# 30     35         20               20           16         30           31
# 48     19         19               20           21         21           39
# 59     10         11                8           17         19           25
# 60     15         21               24           17         31           50
# 62     16         23               27           22         46           72
# ..    ...        ...              ...          ...        ...          ...
# 699    21         19               12           12         21           31
# 700    20         20               15           13         22           32
# 701    20         18               17           15         15           31
# 707    29         27               22           16         25           23
# 709    29         27               22           16         25           23
#
# [164 rows x 13 columns]

# %% [markdown]
# #### ok, that doesn't make real-world sense. Perhaps the shoulder to waist measurement is a diagonal, not a vertical measurement, but there's no info on kaggle about how these measurements were taken. I may eventually abandon this dataset, as I'm developing significant skepticism in it's accuracy.

# %% [markdown]
# ### Line plot of Head circumference by age

# %%
sns.relplot(data=df, x="Age", y="HeadCircumference", kind="line", col="Gender")

# %% [markdown]
# ### Histogram plot of head circumference

# %%
head = sns.displot(data=df, x="Age", y="HeadCircumference", kind="hist", col="Gender")

# %% [markdown]
# ### Saving file as png file type

# %%
head.savefig('head_circumference.png')
